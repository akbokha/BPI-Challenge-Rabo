# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
offers = pd.read_csv("offerEvents.csv")
applications = pd.read_csv("applicationEvents.csv")
applications.head()
# Out:
#                     case                 event                startTime  \
# 0  Application_652823628  A_Create Application  2016/01/01 10:51:15.304
# 1  Application_652823628           A_Submitted  2016/01/01 10:51:15.352
# 2  Application_652823628           A_Submitted  2016/01/01 10:51:15.352
# 3  Application_652823628           A_Submitted  2016/01/01 10:51:15.352
# 4  Application_652823628           A_Submitted  2016/01/01 10:51:15.352
#
#               completeTime                LoanGoal ApplicationType  \
# 0  2016/01/01 10:51:15.304  Existing loan takeover      New credit
# 1  2016/01/01 10:51:15.352  Existing loan takeover      New credit
# 2  2016/01/01 10:51:15.352  Existing loan takeover      New credit
# 3  2016/01/01 10:51:15.352  Existing loan takeover      New credit
# 4  2016/01/01 10:51:15.352  Existing loan takeover      New credit
#
#    RequestedAmount       Action  FirstWithdrawalAmount  NumberOfTerms  \
# 0          20000.0      Created                    NaN            NaN
# 1          20000.0  statechange                    NaN            NaN
# 2          20000.0  statechange                    NaN            NaN
# 3          20000.0  statechange                    NaN            NaN
# 4          20000.0  statechange                    NaN            NaN
#
#   Accepted OfferID  MonthlyCost  EventOrigin                EventID Selected  \
# 0      NaN     NaN          NaN  Application  Application_652823628      NaN
# 1      NaN     NaN          NaN  Application   ApplState_1582051990      NaN
# 2      NaN     NaN          NaN  Application   ApplState_1582051990      NaN
# 3      NaN     NaN          NaN  Application   ApplState_1582051990      NaN
# 4      NaN     NaN          NaN  Application   ApplState_1582051990      NaN
#
#    CreditScore  OfferedAmount
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN

# %%
#uniqueApplications = applications.case.unique()
countEvents = applications.groupby(['case', 'event']).size()
countEvents.head()
# Out:
# case                    event
# Application_1000086665  A_Accepted              1
#                         A_Cancelled             1
#                         A_Complete              4
#                         A_Concept               1
#                         A_Create Application    1
# dtype: int64

# %%
eventsPerApp = countEvents.to_frame(name = "occurences").reset_index()
eventsPerApp.head()
# Out:
#                      case                 event  occurences
# 0  Application_1000086665            A_Accepted           1
# 1  Application_1000086665           A_Cancelled           1
# 2  Application_1000086665            A_Complete           4
# 3  Application_1000086665             A_Concept           1
# 4  Application_1000086665  A_Create Application           1

# %%
incompleteApps = eventsPerApp[eventsPerApp.event =='A_Incomplete'].reset_index()
incompleteApps.head()
# Out:
#    index                    case         event  occurences
# 0     43  Application_1000334415  A_Incomplete           6
# 1     59  Application_1000339879  A_Incomplete           4
# 2     76   Application_100034150  A_Incomplete           8
# 3     94  Application_1000386745  A_Incomplete          10
# 4    151  Application_1000610355  A_Incomplete          10

# %%
endApps = eventsPerApp.loc[(eventsPerApp.event =='A_Pending') 
                       | (eventsPerApp.event =='A_Cancelled') | (eventsPerApp.event =='A_Denied')].reset_index()
endApps.head()
# Out:
#    index                    case        event  occurences
# 0      1  Application_1000086665  A_Cancelled           1
# 1     16  Application_1000158214    A_Pending           2
# 2     28  Application_1000311556  A_Cancelled           1
# 3     42  Application_1000334415     A_Denied           1
# 4     60  Application_1000339879    A_Pending           2

# %%
apps = incompleteApps[['case']]
apps2 = endApps[['case']]
allApps = pd.concat([apps, apps2])
allApps = allApps.drop_duplicates()
allApps.shape
# Out:
# (31456, 1)

# %%
allApps['incompleteFrequency'] = 0
allApps['cancelled'] = False
allApps['pending'] = False
allApps['denied'] = False
allApps.shape
# Out:
# (31456, 5)

# %%
allApps = pd.merge(allApps, endApps)
allApps.pending = allApps.event == 'A_Pending'
allApps.cancelled = allApps.event == 'A_Cancelled'
allApps.denied = allApps.event == 'A_Denied'
allApps.head()
# Out:
#                      case  incompleteFrequency  cancelled  pending  denied  \
# 0  Application_1000334415                    0      False    False    True
# 1  Application_1000339879                    0      False     True   False
# 2   Application_100034150                    0      False     True   False
# 3  Application_1000386745                    0      False     True   False
# 4  Application_1000610355                    0      False    False    True
#
#    index      event  occurences
# 0     42   A_Denied           1
# 1     60  A_Pending           2
# 2     77  A_Pending           2
# 3     95  A_Pending           2
# 4    150   A_Denied           1

# %%
allApps.incompleteFrequency = incompleteApps.occurences
allApps.incompleteFrequency.fillna(0, inplace=True)
allApps.head()
# Out:
#                      case  incompleteFrequency  cancelled  pending  denied  \
# 0  Application_1000334415                  6.0      False    False    True
# 1  Application_1000339879                  4.0      False     True   False
# 2   Application_100034150                  8.0      False     True   False
# 3  Application_1000386745                 10.0      False     True   False
# 4  Application_1000610355                 10.0      False    False    True
#
#    index      event  occurences
# 0     42   A_Denied           1
# 1     60  A_Pending           2
# 2     77  A_Pending           2
# 3     95  A_Pending           2
# 4    150   A_Denied           1

# %%
del allApps['occurences']
del allApps['event']
del allApps['index']

# %%
allApps.head()
# Out:
#                      case  incompleteFrequency  cancelled  pending  denied
# 0  Application_1000334415                  6.0      False    False    True
# 1  Application_1000339879                  4.0      False     True   False
# 2   Application_100034150                  8.0      False     True   False
# 3  Application_1000386745                 10.0      False     True   False
# 4  Application_1000610355                 10.0      False    False    True

# %%
allApps.incompleteFrequency.hist(normed = 0, histtype = "stepfilled", bins = 40)

# %%
#allApps[['incompleteFrequency']]  = allApps[['incompleteFrequency']].apply(lambda x: (x - x.min()) / (x.max() - x.min())) # normalize
#allApps.head()

# %%
incFreq = tf.feature_column.numeric_column('incompleteFrequency')

# %%
allApps['loanGoal'] = applications.LoanGoal
allApps['applicationType'] = applications.ApplicationType
allApps
# Out:
#                          case  incompleteFrequency  cancelled  pending  \
# 0      Application_1000334415                  6.0      False    False
# 1      Application_1000339879                  4.0      False     True
# 2       Application_100034150                  8.0      False     True
# 3      Application_1000386745                 10.0      False     True
# 4      Application_1000610355                 10.0      False    False
# 5      Application_1000671285                  6.0      False     True
# 6      Application_1000956993                 10.0      False     True
# 7      Application_1001114274                  4.0      False     True
# 8      Application_1001177986                 22.0      False     True
# 9      Application_1001274919                  4.0      False     True
# 10     Application_1001484676                  7.0      False     True
# 11     Application_1001624285                  6.0      False     True
# 12     Application_1001858108                 12.0      False     True
# 13     Application_1001866944                 12.0      False     True
# 14     Application_1002013470                  6.0      False    False
# 15     Application_1002129113                 10.0      False     True
# 16      Application_100239804                  6.0      False     True
# 17     Application_1002485344                 33.0       True    False
# 18     Application_1002602375                 36.0      False     True
# 19     Application_1002626536                  6.0      False     True
# 20     Application_1002843616                  4.0      False     True
# 21     Application_1002961837                 12.0      False     True
# 22     Application_1003092772                  8.0      False    False
# 23     Application_1003184938                  6.0      False     True
# 24     Application_1003264681                 18.0      False     True
# 25     Application_1003444518                  1.0       True    False
# 26     Application_1003879772                 25.0      False     True
# 27     Application_1004303396                 31.0      False     True
# 28      Application_100433898                 15.0      False     True
# 29     Application_1004385970                  4.0      False     True
# ...                       ...                  ...        ...      ...
# 31381   Application_995868026                  0.0      False     True
# 31382   Application_995957898                  0.0       True    False
# 31383   Application_996025636                  0.0       True    False
# 31384   Application_996213670                  0.0       True    False
# 31385   Application_996252474                  0.0       True    False
# 31386    Application_99629453                  0.0       True    False
# 31387   Application_996408810                  0.0      False    False
# 31388    Application_99697167                  0.0       True    False
# 31389   Application_997024654                  0.0      False     True
# 31390   Application_997087296                  0.0      False     True
# 31391   Application_997154971                  0.0       True    False
# 31392   Application_997160076                  0.0       True    False
# 31393   Application_997205131                  0.0       True    False
# 31394   Application_997212735                  0.0       True    False
# 31395   Application_997240244                  0.0       True    False
# 31396   Application_997592088                  0.0       True    False
# 31397   Application_997702297                  0.0      False     True
# 31398   Application_998310056                  0.0       True    False
# 31399   Application_998406439                  0.0      False     True
# 31400   Application_998502130                  0.0      False    False
# 31401   Application_998522150                  0.0      False    False
# 31402   Application_998576013                  0.0      False    False
# 31403   Application_998600110                  0.0      False    False
# 31404   Application_998666405                  0.0       True    False
# 31405   Application_998917442                  0.0       True    False
# 31406   Application_999090530                  0.0      False     True
# 31407   Application_999352398                  0.0      False     True
# 31408   Application_999487618                  0.0      False     True
# 31409   Application_999632431                  0.0       True    False
# 31410   Application_999993467                  0.0      False     True
#
#        denied                loanGoal applicationType
# 0        True  Existing loan takeover      New credit
# 1       False  Existing loan takeover      New credit
# 2       False  Existing loan takeover      New credit
# 3       False  Existing loan takeover      New credit
# 4        True  Existing loan takeover      New credit
# 5       False  Existing loan takeover      New credit
# 6       False  Existing loan takeover      New credit
# 7       False  Existing loan takeover      New credit
# 8       False  Existing loan takeover      New credit
# 9       False  Existing loan takeover      New credit
# 10      False  Existing loan takeover      New credit
# 11      False  Existing loan takeover      New credit
# 12      False  Existing loan takeover      New credit
# 13      False  Existing loan takeover      New credit
# 14       True  Existing loan takeover      New credit
# 15      False  Existing loan takeover      New credit
# 16      False  Existing loan takeover      New credit
# 17      False  Existing loan takeover      New credit
# 18      False  Existing loan takeover      New credit
# 19      False  Existing loan takeover      New credit
# 20      False  Existing loan takeover      New credit
# 21      False  Existing loan takeover      New credit
# 22       True  Existing loan takeover      New credit
# 23      False  Existing loan takeover      New credit
# 24      False  Existing loan takeover      New credit
# 25      False  Existing loan takeover      New credit
# 26      False  Existing loan takeover      New credit
# 27      False  Existing loan takeover      New credit
# 28      False  Existing loan takeover      New credit
# 29      False  Existing loan takeover      New credit
# ...       ...                     ...             ...
# 31381   False        Home improvement      New credit
# 31382   False        Home improvement      New credit
# 31383   False        Home improvement      New credit
# 31384   False        Home improvement      New credit
# 31385   False        Home improvement      New credit
# 31386   False        Home improvement      New credit
# 31387    True        Home improvement      New credit
# 31388   False        Home improvement      New credit
# 31389   False        Home improvement      New credit
# 31390   False        Home improvement      New credit
# 31391   False        Home improvement      New credit
# 31392   False        Home improvement      New credit
# 31393   False        Home improvement      New credit
# 31394   False        Home improvement      New credit
# 31395   False        Home improvement      New credit
# 31396   False                     Car      New credit
# 31397   False                     Car      New credit
# 31398   False                     Car      New credit
# 31399   False                     Car      New credit
# 31400    True                     Car      New credit
# 31401    True                     Car      New credit
# 31402    True                     Car      New credit
# 31403    True                     Car      New credit
# 31404   False                     Car      New credit
# 31405   False                     Car      New credit
# 31406   False                     Car      New credit
# 31407   False                     Car      New credit
# 31408   False                     Car      New credit
# 31409   False                     Car      New credit
# 31410   False                     Car      New credit
#
# [31411 rows x 7 columns]

# %%
allApps.loanGoal.unique()
# Out:
# array(['Existing loan takeover', 'Home improvement', 'Car',
#        'Other, see explanation', 'Remaining debt home', 'Not speficied',
#        'Unknown', 'Caravan / Camper', 'Tax payments',
#        'Extra spending limit', 'Motorcycle', 'Boat', 'Business goal'], dtype=object)

# %%
allApps.applicationType.unique()
# Out:
# array(['New credit', 'Limit raise'], dtype=object)

# %%
loanGoal = tf.feature_column.categorical_column_with_vocabulary_list('loanGoal',
                                                                           ['Existing loan takeover',
                                                                            'Home improvement', 'Car',
                                                                            'Other, see explanation',
                                                                            'Remaining debt home', 'Not speficied',
                                                                            'Unknown', 'Caravan / Camper', 'Tax payments',
                                                                            'Extra spending limit', 'Motorcycle', 'Boat',
                                                                            'Business goal'])
applicationType = tf.feature_column.categorical_column_with_vocabulary_list('applicationType',
                                                                           ['New credit', 'Limit raise'])

# %%
feat_cols = [incFreq, loanGoal, applicationType]

# %%
allApps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31411 entries, 0 to 31410
# Data columns (total 7 columns):
# case                   31411 non-null object
# incompleteFrequency    31411 non-null float64
# cancelled              31411 non-null bool
# pending                31411 non-null bool
# denied                 31411 non-null bool
# loanGoal               31411 non-null object
# applicationType        31411 non-null object
# dtypes: bool(3), float64(1), object(3)
# memory usage: 1.3+ MB

# %%
feat_data = allApps.drop('pending', axis = 1)

# %%
labels = allApps['pending']

# %%
x_train, x_test, y_train, y_test = train_test_split(feat_data, labels, test_size = 0.3)

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x = x_train, y = y_train, batch_size=100, num_epochs=1000, shuffle=True)

# %%
model = tf.estimator.LinearClassifier(feature_columns = feat_cols, n_classes = 2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\s158881\AppData\Local\Temp\tmpbxkxoc1j
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\s158881\\AppData\\Local\\Temp\\tmpbxkxoc1j', '_tf_random_seed': 1, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_save_checkpoints_steps': None, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100}

# %%
model.train(input_fn = input_func, steps = 1000)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\s158881\AppData\Local\Temp\tmpbxkxoc1j\model.ckpt.
# INFO:tensorflow:loss = 69.3147, step = 1
# INFO:tensorflow:global_step/sec: 499.65
# INFO:tensorflow:loss = 56.4306, step = 101 (0.203 sec)
# INFO:tensorflow:global_step/sec: 558.268
# INFO:tensorflow:loss = 72.6502, step = 201 (0.178 sec)
# INFO:tensorflow:global_step/sec: 569.401
# INFO:tensorflow:loss = 56.857, step = 301 (0.176 sec)
# INFO:tensorflow:global_step/sec: 576.145
# INFO:tensorflow:loss = 52.5251, step = 401 (0.174 sec)
# INFO:tensorflow:global_step/sec: 562.986
# INFO:tensorflow:loss = 51.3871, step = 501 (0.178 sec)
# INFO:tensorflow:global_step/sec: 567.782
# INFO:tensorflow:loss = 49.8383, step = 601 (0.176 sec)
# INFO:tensorflow:global_step/sec: 576.89
# INFO:tensorflow:loss = 62.843, step = 701 (0.173 sec)
# INFO:tensorflow:global_step/sec: 579.306
# INFO:tensorflow:loss = 48.7205, step = 801 (0.172 sec)
# INFO:tensorflow:global_step/sec: 557.701
# INFO:tensorflow:loss = 56.2204, step = 901 (0.180 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\s158881\AppData\Local\Temp\tmpbxkxoc1j\model.ckpt.
# INFO:tensorflow:Loss for final step: 62.4842.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x = x_test,
      y = y_test,
      batch_size = 100,
      num_epochs = 1,
      shuffle = False)

# %%
results = model.evaluate(eval_input_func)
results
# Out:
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-23-10:00:40
# INFO:tensorflow:Restoring parameters from C:\Users\s158881\AppData\Local\Temp\tmpbxkxoc1j\model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-11-23-10:00:41
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.775785, accuracy_baseline = 0.552525, auc = 0.791939, auc_precision_recall = 0.806018, average_loss = 0.57118, global_step = 1000, label/mean = 0.552525, loss = 56.6611, prediction/mean = 0.559934
# {'accuracy': 0.77578521,
#  'accuracy_baseline': 0.55252546,
#  'auc': 0.79193878,
#  'auc_precision_recall': 0.80601835,
#  'average_loss': 0.57118005,
#  'global_step': 1000,
#  'label/mean': 0.55252546,
#  'loss': 56.66106,
#  'prediction/mean': 0.55993354}
