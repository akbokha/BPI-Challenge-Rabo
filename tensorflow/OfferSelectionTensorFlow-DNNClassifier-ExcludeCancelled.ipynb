# %% [markdown]
# ### <font color="darkblue"><i>A predictive model which tries to predict whether customers will accept a loan offer or not. The model uses only features that will be known at the time of sending an offer. Once the performance metrics of the model have been assessed and the performance (e.g. accuracy) is evaluated to be adequate enough, the model can be used by employees before sending the actual offers. If the model predicts that the offer will not be accepted (i.e. will be refused and/or cancelled) with a high probability, the employee can chose to change the offer and/or not send an offer / send multiple offers. This can reduce the company's overhead/resources in the offer sending process.</i></font>

# %% [markdown]
# ### <font color="green">imports, preparation and configuration</font>

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import preprocessing, metrics
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from IPython.display import HTML
HTML('''<script>
code_show_err=false; 
function code_toggle_err() {
 if (code_show_err){
 $('div.output_stderr').hide();
 } else {
 $('div.output_stderr').show();
 }
 code_show_err = !code_show_err
} 
$( document ).ready(code_toggle_err);
</script>
To toggle on/off output_stderr, click <a href="javascript:code_toggle_err()">here</a>.''')
# Out:
# <script>
# code_show_err=false;
# function code_toggle_err() {
#  if (code_show_err){
#  $('div.output_stderr').hide();
#  } else {
#  $('div.output_stderr').show();
#  }
#  code_show_err = !code_show_err
# }
# $( document ).ready(code_toggle_err);
# </script>
# To toggle on/off output_stderr, click <a href="javascript:code_toggle_err()">here</a>.

# %%
offers = pd.read_table("../data/laraData/offer_events.csv", sep=";")
applications = pd.read_table("../data/laraData/application_events.csv", sep=";")
# all_events = pd.read_table("../data/laraData/events.csv", sep=";") not needed at the moment
applications.head()
# Out:
#      A_ID             A_DT_CREATED  A_INIT_REQ_AMT A_USER_CREATED  \
# 0  719696  1/1/2017 2:42:29,064000         29000.0         USER_1
# 1  719696  1/1/2017 2:42:29,064000         29000.0         USER_1
# 2  719696  1/1/2017 2:42:29,064000         29000.0         USER_1
# 3  719696  1/1/2017 2:42:29,064000         29000.0         USER_1
# 4  719696  1/1/2017 2:42:29,064000         29000.0         USER_1
#
#    A_APPLICATIONTYPE A_APPLICATIONTYPE_DESC  A_LOANGOALTYPE  \
# 0                520          Nieuw krediet           866.0
# 1                520          Nieuw krediet           866.0
# 2                520          Nieuw krediet           866.0
# 3                520          Nieuw krediet           866.0
# 4                520          Nieuw krediet           866.0
#
#   A_LOANGOALTYPE_DESC    AS_ID  AS_APPLICATIONSTATE        ...         \
# 0                Auto  1453642                  511        ...
# 1                Auto  1454067                  513        ...
# 2                Auto  1458788                  517        ...
# 3                Auto  1456650                  516        ...
# 4                Auto  1453643                  512        ...
#
#   NUMBER_OF_CHILDREN MARITAL_STATUS    SEX HOUSING_TYPE  SCE_CREDITSCORE  \
# 0                0.0    Samenwonend  Vrouw     Koophuis            784.0
# 1                0.0    Samenwonend  Vrouw     Koophuis            784.0
# 2                0.0    Samenwonend  Vrouw     Koophuis            784.0
# 3                0.0    Samenwonend  Vrouw     Koophuis            784.0
# 4                0.0    Samenwonend  Vrouw     Koophuis            784.0
#
#    SCE_ACCEPTED SCE_ACCEPTED_OVERRIDE  SCE_MAX_AMOUNT SCE_MAX_AMOUNT_OVERRIDE  \
# 0           1.0                   1.0         49340.0                 49340.0
# 1           1.0                   1.0         49340.0                 49340.0
# 2           1.0                   1.0         49340.0                 49340.0
# 3           1.0                   1.0         49340.0                 49340.0
# 4           1.0                   1.0         49340.0                 49340.0
#
#   INCOMEAMOUNT_YEAR
# 0           41088.0
# 1           41088.0
# 2           41088.0
# 3           41088.0
# 4           41088.0
#
# [5 rows x 27 columns]

# %%
offers.head()
# Out:
#      A_ID    O_ID  O_SCENARIO              O_DT_CREATED  O_AMOUNT  \
# 0  719696  210708     1367858  2/1/2017 10:38:26,536000   29000.0
# 1  719696  210708     1367858  2/1/2017 10:38:26,536000   29000.0
# 2  719696  210708     1367858  2/1/2017 10:38:26,536000   29000.0
# 3  719696  210708     1367858  2/1/2017 10:38:26,536000   29000.0
# 4  719697  210793     1367861  2/1/2017 16:08:07,608000   10000.0
#
#    O_CREDITSCORE  O_FIRST_WITHDRAWL_AMOUNT  NUMBER_OF_TERMS  O_MONTHLY_COST  \
# 0          784.0                   26604.0              120           29529
# 1          784.0                   26604.0              120           29529
# 2          784.0                   26604.0              120           29529
# 3          784.0                   26604.0              120           29529
# 4            NaN                   10000.0               44           24958
#
#    O_ACCEPTED           ...            NUMBER_OF_CHILDREN  MARITAL_STATUS  \
# 0           1           ...                             0     Samenwonend
# 1           1           ...                             0     Samenwonend
# 2           1           ...                             0     Samenwonend
# 3           1           ...                             0     Samenwonend
# 4           1           ...                             0    Alleenstaand
#
#      SEX           HOUSING_TYPE  INCOMEAMOUNT_YEAR SCE_CREDITSCORE  \
# 0  Vrouw               Koophuis            41088.0           784.0
# 1  Vrouw               Koophuis            41088.0           784.0
# 2  Vrouw               Koophuis            41088.0           784.0
# 3  Vrouw               Koophuis            41088.0           784.0
# 4    Man  Thuiswonend/ Inwonend            21600.0           708.0
#
#   SCE_ACCEPTED  SCE_ACCEPTED_OVERRIDE  SCE_MAX_AMOUNT SCE_MAX_AMOUNT_OVERRIDE
# 0          1.0                    1.0         49340.0                 49340.0
# 1          1.0                    1.0         49340.0                 49340.0
# 2          1.0                    1.0         49340.0                 49340.0
# 3          1.0                    1.0         49340.0                 49340.0
# 4          1.0                    1.0        235875.0                235875.0
#
# [5 rows x 30 columns]

# %% [markdown]
# O_SELECTED tells us whetehr an offer is accepted(1)/or refused/cancelled (0)

# %%
made_offers = offers[pd.notnull(offers.O_SELECTED)]
made_offers.shape
# Out:
# (118931, 30)

# %%
made_offers.OS_OFFERSTATE_DESC.hist()

# %%
len(made_offers.O_ID.unique())
# Out:
# 33401

# %%
cancelled = made_offers.copy()

# %%
are_cancelled = cancelled[cancelled.event == 'O_Cancelled'].O_ID.unique()
# Out:
# array([210793, 210794, 210961, ..., 244653, 244754, 244965], dtype=int64)

# %%
import math

# %%
cancelled["is_cancelled"] = np.nan
cancelled["is_cancelled"] = cancelled[cancelled.O_ID.isin(are_cancelled)]
cancelled.loc[(cancelled['is_cancelled'] > 0), 'is_cancelled'] = True
cancelled[['is_cancelled']] = cancelled[['is_cancelled']].fillna(value = False)
# Out:
#           A_ID    O_ID  O_SCENARIO                O_DT_CREATED  O_AMOUNT  \
# 0       719696  210708     1367858    2/1/2017 10:38:26,536000   29000.0
# 1       719696  210708     1367858    2/1/2017 10:38:26,536000   29000.0
# 2       719696  210708     1367858    2/1/2017 10:38:26,536000   29000.0
# 3       719696  210708     1367858    2/1/2017 10:38:26,536000   29000.0
# 4       719697  210793     1367861    2/1/2017 16:08:07,608000   10000.0
# 5       719697  210794     1367861    2/1/2017 16:09:04,325000   13000.0
# 6       719697  210794     1367861    2/1/2017 16:09:04,325000   13000.0
# 7       719697  210793     1367861    2/1/2017 16:08:07,608000   10000.0
# 8       719697  210794     1367861    2/1/2017 16:09:04,325000   13000.0
# 9       719697  210793     1367861    2/1/2017 16:08:07,608000   10000.0
# 10      719698  210961     1367866    3/1/2017 16:10:34,510000    8000.0
# 11      719698  210961     1367866    3/1/2017 16:10:34,510000    8000.0
# 12      719698  210961     1367866    3/1/2017 16:10:34,510000    8000.0
# 13      719699  212234     1367869   13/1/2017 13:39:27,664000    5000.0
# 14      719699  210814     1367869    2/1/2017 17:22:18,492000    5000.0
# 15      719699  210814     1367869    2/1/2017 17:22:18,492000    5000.0
# 16      719699  212234     1367869   13/1/2017 13:39:27,664000    5000.0
# 17      719699  212234     1367869   13/1/2017 13:39:27,664000    5000.0
# 18      719699  210814     1367869    2/1/2017 17:22:18,492000    5000.0
# 19      719699  210814     1367869    2/1/2017 17:22:18,492000    5000.0
# 20      719701  211658     1367878    9/1/2017 15:32:34,085000   22000.0
# 21      719701  210788     1367878    2/1/2017 15:52:02,657000   25000.0
# 22      719701  211658     1367878    9/1/2017 15:32:34,085000   22000.0
# 23      719701  211658     1367878    9/1/2017 15:32:34,085000   22000.0
# 24      719701  210788     1367878    2/1/2017 15:52:02,657000   25000.0
# 25      719701  210788     1367878    2/1/2017 15:52:02,657000   25000.0
# 26      719701  210788     1367878    2/1/2017 15:52:02,657000   25000.0
# 27      719701  211658     1367878    9/1/2017 15:32:34,085000   22000.0
# 28      719702  210833     1367880    2/1/2017 19:42:25,280000   13000.0
# 29      719702  210833     1367880    2/1/2017 19:42:25,280000   13000.0
# ...        ...     ...         ...                         ...       ...
# 118901  786532  244780     1618309   3/10/2017 15:12:21,590000   15000.0
# 118902  786532  244780     1618309   3/10/2017 15:12:21,590000   15000.0
# 118903  786532  244780     1618309   3/10/2017 15:12:21,590000   15000.0
# 118904  786532  244780     1618309   3/10/2017 15:12:21,590000   15000.0
# 118905  786535  244757     1618322   3/10/2017 13:47:34,542000   11000.0
# 118906  786535  244757     1618322   3/10/2017 13:47:34,542000   11000.0
# 118907  786535  244757     1618322   3/10/2017 13:47:34,542000   11000.0
# 118908  786539  244718     1618338   3/10/2017 10:49:57,606000   50000.0
# 118909  786539  244718     1618338   3/10/2017 10:49:57,606000   50000.0
# 118910  786539  244718     1618338   3/10/2017 10:49:57,606000   50000.0
# 118911  786545  244709     1618359   3/10/2017 10:05:53,961000   15000.0
# 118912  786545  244709     1618359   3/10/2017 10:05:53,961000   15000.0
# 118913  786545  244709     1618359   3/10/2017 10:05:53,961000   15000.0
# 118914  786545  244709     1618359   3/10/2017 10:05:53,961000   15000.0
# 118915  786548  245816     1618374  11/10/2017 20:45:39,899000   14500.0
# 118916  786548  245816     1618374  11/10/2017 20:45:39,899000   14500.0
# 118917  786550  244819     1618378   3/10/2017 18:28:33,044000   75000.0
# 118918  786550  244819     1618378   3/10/2017 18:28:33,044000   75000.0
# 118919  786550  244819     1618378   3/10/2017 18:28:33,044000   75000.0
# 118920  786550  244819     1618378   3/10/2017 18:28:33,044000   75000.0
# 118921  786552  244965     1618390   4/10/2017 17:54:20,845000   21500.0
# 118922  786552  244965     1618390   4/10/2017 17:54:20,845000   21500.0
# 118923  786552  244965     1618390   4/10/2017 17:54:20,845000   21500.0
# 118924  786552  244965     1618390   4/10/2017 17:54:20,845000   21500.0
# 118925  786559  244839     1618414   3/10/2017 19:52:01,271000   15000.0
# 118926  786559  244839     1618414   3/10/2017 19:52:01,271000   15000.0
# 118927  786560  244719     1618418   3/10/2017 10:51:13,174000   35300.0
# 118928  786560  244720     1618416   3/10/2017 10:51:43,086000   35300.0
# 118929  786560  244720     1618416   3/10/2017 10:51:43,086000   35300.0
# 118930  786560  244719     1618418   3/10/2017 10:51:13,174000   35300.0
#
#         O_CREDITSCORE  O_FIRST_WITHDRAWL_AMOUNT  NUMBER_OF_TERMS  \
# 0               784.0                   26604.0              120
# 1               784.0                   26604.0              120
# 2               784.0                   26604.0              120
# 3               784.0                   26604.0              120
# 4                 NaN                   10000.0               44
# 5                 NaN                   13000.0               57
# 6                 NaN                   13000.0               57
# 7                 NaN                   10000.0               44
# 8                 NaN                   13000.0               57
# 9                 NaN                   10000.0               44
# 10                NaN                    8000.0              120
# 11                NaN                    8000.0              120
# 12                NaN                    8000.0              120
# 13                NaN                  175503.0               60
# 14              719.0                  175503.0               60
# 15              719.0                  175503.0               60
# 16                NaN                  175503.0               60
# 17                NaN                  175503.0               60
# 18              719.0                  175503.0               60
# 19              719.0                  175503.0               60
# 20              776.0                   22000.0              120
# 21                NaN                   25000.0              120
# 22              776.0                   22000.0              120
# 23              776.0                   22000.0              120
# 24                NaN                   25000.0              120
# 25                NaN                   25000.0              120
# 26                NaN                   25000.0              120
# 27              776.0                   22000.0              120
# 28                NaN                    3500.0              134
# 29                NaN                    3500.0              134
# ...               ...                       ...              ...
# 118901          839.0                   15000.0               60
# 118902          839.0                   15000.0               60
# 118903          839.0                   15000.0               60
# 118904          839.0                   15000.0               60
# 118905            NaN                   11000.0              120
# 118906            NaN                   11000.0              120
# 118907            NaN                   11000.0              120
# 118908            NaN                   50000.0               98
# 118909            NaN                   50000.0               98
# 118910            NaN                   50000.0               98
# 118911          853.0                   15000.0               56
# 118912          853.0                   15000.0               56
# 118913          853.0                   15000.0               56
# 118914          853.0                   15000.0               56
# 118915            NaN                   14500.0              110
# 118916            NaN                   14500.0              110
# 118917            NaN                    2722.0              120
# 118918            NaN                    2722.0              120
# 118919            NaN                    2722.0              120
# 118920            NaN                    2722.0              120
# 118921            NaN                   21500.0               72
# 118922            NaN                   21500.0               72
# 118923            NaN                   21500.0               72
# 118924            NaN                   21500.0               72
# 118925            NaN                   15000.0               88
# 118926            NaN                   15000.0               88
# 118927            NaN                       0.0              105
# 118928            NaN                       0.0              108
# 118929            NaN                       0.0              108
# 118930            NaN                       0.0              105
#
#         O_MONTHLY_COST  O_ACCEPTED     ...       MARITAL_STATUS    SEX  \
# 0                29529           1     ...          Samenwonend  Vrouw
# 1                29529           1     ...          Samenwonend  Vrouw
# 2                29529           1     ...          Samenwonend  Vrouw
# 3                29529           1     ...          Samenwonend  Vrouw
# 4                24958           1     ...         Alleenstaand    Man
# 5                25717           0     ...         Alleenstaand    Man
# 6                25717           0     ...         Alleenstaand    Man
# 7                24958           1     ...         Alleenstaand    Man
# 8                25717           0     ...         Alleenstaand    Man
# 9                24958           1     ...         Alleenstaand    Man
# 10                9008           1     ...          Samenwonend    Man
# 11                9008           1     ...          Samenwonend    Man
# 12                9008           1     ...          Samenwonend    Man
# 13                 974           1     ...         Alleenstaand  Vrouw
# 14                 974           1     ...         Alleenstaand  Vrouw
# 15                 974           1     ...         Alleenstaand  Vrouw
# 16                 974           1     ...         Alleenstaand  Vrouw
# 17                 974           1     ...         Alleenstaand  Vrouw
# 18                 974           1     ...         Alleenstaand  Vrouw
# 19                 974           1     ...         Alleenstaand  Vrouw
# 20               22603           0     ...         Alleenstaand    Man
# 21               25456           0     ...         Alleenstaand    Man
# 22               22603           0     ...         Alleenstaand    Man
# 23               22603           0     ...         Alleenstaand    Man
# 24               25456           0     ...         Alleenstaand    Man
# 25               25456           0     ...         Alleenstaand    Man
# 26               25456           0     ...         Alleenstaand    Man
# 27               22603           0     ...         Alleenstaand    Man
# 28                 130           0     ...         Alleenstaand    Man
# 29                 130           0     ...         Alleenstaand    Man
# ...                ...         ...     ...                  ...    ...
# 118901           27838           1     ...               Gehuwd  Vrouw
# 118902           27838           1     ...               Gehuwd  Vrouw
# 118903           27838           1     ...               Gehuwd  Vrouw
# 118904           27838           1     ...               Gehuwd  Vrouw
# 118905            1171           0     ...         Alleenstaand    Man
# 118906            1171           0     ...         Alleenstaand    Man
# 118907            1171           0     ...         Alleenstaand    Man
# 118908           60174           1     ...               Gehuwd  Vrouw
# 118909           60174           1     ...               Gehuwd  Vrouw
# 118910           60174           1     ...               Gehuwd  Vrouw
# 118911             300           1     ...         Alleenstaand  Vrouw
# 118912             300           1     ...         Alleenstaand  Vrouw
# 118913             300           1     ...         Alleenstaand  Vrouw
# 118914             300           1     ...         Alleenstaand  Vrouw
# 118915           16516           1     ...               Gehuwd  Vrouw
# 118916           16516           1     ...               Gehuwd  Vrouw
# 118917           76367           1     ...               Gehuwd  Vrouw
# 118918           76367           1     ...               Gehuwd  Vrouw
# 118919           76367           1     ...               Gehuwd  Vrouw
# 118920           76367           1     ...               Gehuwd  Vrouw
# 118921           33945           1     ...               Gehuwd  Vrouw
# 118922           33945           1     ...               Gehuwd  Vrouw
# 118923           33945           1     ...               Gehuwd  Vrouw
# 118924           33945           1     ...               Gehuwd  Vrouw
# 118925           19914           1     ...          Samenwonend  Vrouw
# 118926           19914           1     ...          Samenwonend  Vrouw
# 118927           40101           1     ...               Gehuwd  Vrouw
# 118928             400           1     ...               Gehuwd  Vrouw
# 118929             400           1     ...               Gehuwd  Vrouw
# 118930           40101           1     ...               Gehuwd  Vrouw
#
#                  HOUSING_TYPE INCOMEAMOUNT_YEAR  SCE_CREDITSCORE SCE_ACCEPTED  \
# 0                    Koophuis           41088.0            784.0          1.0
# 1                    Koophuis           41088.0            784.0          1.0
# 2                    Koophuis           41088.0            784.0          1.0
# 3                    Koophuis           41088.0            784.0          1.0
# 4       Thuiswonend/ Inwonend           21600.0            708.0          1.0
# 5       Thuiswonend/ Inwonend           21600.0            708.0          1.0
# 6       Thuiswonend/ Inwonend           21600.0            708.0          1.0
# 7       Thuiswonend/ Inwonend           21600.0            708.0          1.0
# 8       Thuiswonend/ Inwonend           21600.0            708.0          1.0
# 9       Thuiswonend/ Inwonend           21600.0            708.0          1.0
# 10      Thuiswonend/ Inwonend           22800.0            805.0          1.0
# 11      Thuiswonend/ Inwonend           22800.0            805.0          1.0
# 12      Thuiswonend/ Inwonend           22800.0            805.0          1.0
# 13          Huurhuis / Kamers           18000.0            719.0          1.0
# 14          Huurhuis / Kamers           18000.0            719.0          1.0
# 15          Huurhuis / Kamers           18000.0            719.0          1.0
# 16          Huurhuis / Kamers           18000.0            719.0          1.0
# 17          Huurhuis / Kamers           18000.0            719.0          1.0
# 18          Huurhuis / Kamers           18000.0            719.0          1.0
# 19          Huurhuis / Kamers           18000.0            719.0          1.0
# 20          Huurhuis / Kamers           27330.0            776.0          1.0
# 21          Huurhuis / Kamers           27330.0            776.0          1.0
# 22          Huurhuis / Kamers           27330.0            776.0          1.0
# 23          Huurhuis / Kamers           27330.0            776.0          1.0
# 24          Huurhuis / Kamers           27330.0            776.0          1.0
# 25          Huurhuis / Kamers           27330.0            776.0          1.0
# 26          Huurhuis / Kamers           27330.0            776.0          1.0
# 27          Huurhuis / Kamers           27330.0            776.0          1.0
# 28      Thuiswonend/ Inwonend           19224.0            683.0          1.0
# 29      Thuiswonend/ Inwonend           19224.0            683.0          1.0
# ...                       ...               ...              ...          ...
# 118901               Koophuis           47400.0            839.0          1.0
# 118902               Koophuis           47400.0            839.0          1.0
# 118903               Koophuis           47400.0            839.0          1.0
# 118904               Koophuis           47400.0            839.0          1.0
# 118905      Huurhuis / Kamers           25008.0            698.0          1.0
# 118906      Huurhuis / Kamers           25008.0            698.0          1.0
# 118907      Huurhuis / Kamers           25008.0            698.0          1.0
# 118908               Koophuis           84795.0            943.0          1.0
# 118909               Koophuis           84795.0            943.0          1.0
# 118910               Koophuis           84795.0            943.0          1.0
# 118911               Koophuis           28656.0            853.0          1.0
# 118912               Koophuis           28656.0            853.0          1.0
# 118913               Koophuis           28656.0            853.0          1.0
# 118914               Koophuis           28656.0            853.0          1.0
# 118915               Koophuis           36768.0            816.0          1.0
# 118916               Koophuis           36768.0            816.0          1.0
# 118917               Koophuis           51926.0            825.0          1.0
# 118918               Koophuis           51926.0            825.0          1.0
# 118919               Koophuis           51926.0            825.0          1.0
# 118920               Koophuis           51926.0            825.0          1.0
# 118921               Koophuis           46200.0            978.0          1.0
# 118922               Koophuis           46200.0            978.0          1.0
# 118923               Koophuis           46200.0            978.0          1.0
# 118924               Koophuis           46200.0            978.0          1.0
# 118925               Koophuis           52290.0            922.0          1.0
# 118926               Koophuis           52290.0            922.0          1.0
# 118927               Koophuis           69900.0            917.0          1.0
# 118928               Koophuis           69900.0            917.0          1.0
# 118929               Koophuis           69900.0            917.0          1.0
# 118930               Koophuis           69900.0            917.0          1.0
#
#        SCE_ACCEPTED_OVERRIDE  SCE_MAX_AMOUNT  SCE_MAX_AMOUNT_OVERRIDE  \
# 0                        1.0         49340.0                  49340.0
# 1                        1.0         49340.0                  49340.0
# 2                        1.0         49340.0                  49340.0
# 3                        1.0         49340.0                  49340.0
# 4                        1.0        235875.0                 235875.0
# 5                        1.0        235875.0                 235875.0
# 6                        1.0        235875.0                 235875.0
# 7                        1.0        235875.0                 235875.0
# 8                        1.0        235875.0                 235875.0
# 9                        1.0        235875.0                 235875.0
# 10                       1.0          8245.0                   8245.0
# 11                       1.0          8245.0                   8245.0
# 12                       1.0          8245.0                   8245.0
# 13                       1.0         58375.0                  58375.0
# 14                       1.0         58375.0                  58375.0
# 15                       1.0         58375.0                  58375.0
# 16                       1.0         58375.0                  58375.0
# 17                       1.0         58375.0                  58375.0
# 18                       1.0         58375.0                  58375.0
# 19                       1.0         58375.0                  58375.0
# 20                       1.0        324765.0                  33778.0
# 21                       1.0        324765.0                  33778.0
# 22                       1.0        324765.0                  33778.0
# 23                       1.0        324765.0                  33778.0
# 24                       1.0        324765.0                  33778.0
# 25                       1.0        324765.0                  33778.0
# 26                       1.0        324765.0                  33778.0
# 27                       1.0        324765.0                  33778.0
# 28                       1.0        151725.0                 151725.0
# 29                       1.0        151725.0                 151725.0
# ...                      ...             ...                      ...
# 118901                   1.0        831275.0                 831275.0
# 118902                   1.0        831275.0                 831275.0
# 118903                   1.0        831275.0                 831275.0
# 118904                   1.0        831275.0                 831275.0
# 118905                   1.0         20870.0                  20870.0
# 118906                   1.0         20870.0                  20870.0
# 118907                   1.0         20870.0                  20870.0
# 118908                   1.0        100000.0                 100000.0
# 118909                   1.0        100000.0                 100000.0
# 118910                   1.0        100000.0                 100000.0
# 118911                   1.0         31865.0                  31865.0
# 118912                   1.0         31865.0                  31865.0
# 118913                   1.0         31865.0                  31865.0
# 118914                   1.0         31865.0                  31865.0
# 118915                   1.0         55500.0                  55500.0
# 118916                   1.0         55500.0                  55500.0
# 118917                   1.0        100000.0                 100000.0
# 118918                   1.0        100000.0                 100000.0
# 118919                   1.0        100000.0                 100000.0
# 118920                   1.0        100000.0                 100000.0
# 118921                   1.0        100000.0                 100000.0
# 118922                   1.0        100000.0                 100000.0
# 118923                   1.0        100000.0                 100000.0
# 118924                   1.0        100000.0                 100000.0
# 118925                   1.0         66331.0                  99975.0
# 118926                   1.0         66331.0                  99975.0
# 118927                   1.0        100000.0                 100000.0
# 118928                   1.0        100000.0                 100000.0
# 118929                   1.0        100000.0                 100000.0
# 118930                   1.0        100000.0                 100000.0
#
#        is_cancelled
# 0             False
# 1             False
# 2             False
# 3             False
# 4              True
# 5              True
# 6              True
# 7              True
# 8              True
# 9              True
# 10             True
# 11             True
# 12             True
# 13             True
# 14            False
# 15            False
# 16             True
# 17             True
# 18            False
# 19            False
# 20            False
# 21             True
# 22            False
# 23            False
# 24             True
# 25             True
# 26             True
# 27            False
# 28            False
# 29            False
# ...             ...
# 118901        False
# 118902        False
# 118903        False
# 118904        False
# 118905        False
# 118906        False
# 118907        False
# 118908        False
# 118909        False
# 118910        False
# 118911        False
# 118912        False
# 118913        False
# 118914        False
# 118915        False
# 118916        False
# 118917        False
# 118918        False
# 118919        False
# 118920        False
# 118921         True
# 118922         True
# 118923         True
# 118924         True
# 118925        False
# 118926        False
# 118927        False
# 118928        False
# 118929        False
# 118930        False
#
# [118931 rows x 31 columns]

# %%
corr = cancelled.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
len(cancelled[cancelled.O_SELECTED == 1]) / len(cancelled.O_SELECTED == 0)
# Out:
# 0.07467380394780863

# %%
cancelled.O_ID.unique()
# Out:
# array([210793, 210794, 210961, ..., 244653, 244754, 244965], dtype=int64)

# %%
made_offers = (made_offers.loc[(made_offers.event == "O_Accepted") 
                | (made_offers.event == "O_Refused")])

# %%
len(made_offers.O_ID.unique()), made_offers.shape
# Out:
# (18102, (18102, 30))

# %%
made_offers.head()
# Out:
#       A_ID    O_ID  O_SCENARIO              O_DT_CREATED  O_AMOUNT  \
# 0   719696  210708     1367858  2/1/2017 10:38:26,536000   29000.0
# 15  719699  210814     1367869  2/1/2017 17:22:18,492000    5000.0
# 23  719701  211658     1367878  9/1/2017 15:32:34,085000   22000.0
# 29  719702  210833     1367880  2/1/2017 19:42:25,280000   13000.0
# 35  719705  210832     1367893  2/1/2017 19:42:21,339000   10500.0
#
#     O_CREDITSCORE  O_FIRST_WITHDRAWL_AMOUNT  NUMBER_OF_TERMS  O_MONTHLY_COST  \
# 0           784.0                   26604.0              120           29529
# 15          719.0                  175503.0               60             974
# 23          776.0                   22000.0              120           22603
# 29            NaN                    3500.0              134             130
# 35          982.0                   10500.0               60           19853
#
#     O_ACCEPTED           ...            NUMBER_OF_CHILDREN  MARITAL_STATUS  \
# 0            1           ...                             0     Samenwonend
# 15           1           ...                             0    Alleenstaand
# 23           0           ...                             0    Alleenstaand
# 29           0           ...                             0    Alleenstaand
# 35           1           ...                             0          Gehuwd
#
#       SEX           HOUSING_TYPE  INCOMEAMOUNT_YEAR SCE_CREDITSCORE  \
# 0   Vrouw               Koophuis            41088.0           784.0
# 15  Vrouw      Huurhuis / Kamers            18000.0           719.0
# 23    Man      Huurhuis / Kamers            27330.0           776.0
# 29    Man  Thuiswonend/ Inwonend            19224.0           683.0
# 35  Vrouw               Koophuis            48282.0           982.0
#
#    SCE_ACCEPTED  SCE_ACCEPTED_OVERRIDE  SCE_MAX_AMOUNT SCE_MAX_AMOUNT_OVERRIDE
# 0           1.0                    1.0         49340.0                 49340.0
# 15          1.0                    1.0         58375.0                 58375.0
# 23          1.0                    1.0        324765.0                 33778.0
# 29          1.0                    1.0        151725.0                151725.0
# 35          1.0                    1.0        791635.0                 81545.0
#
# [5 rows x 30 columns]

# %% [markdown]
# Features that are going to be considered:
# * Marital status (e.g. married, single, divorced, widowed)
# * Housing type (e.g. owner occupied property, rental property etc)
# * Yearly income amount (yearly) (if married and/or living together: yearly income of partners)
# * Number of children
# * Sex (Male, Female)
# * Age (2017 - birthyear)
# * <b>O_Amount</b> (offered amount by bank; does not need to be equal to request amount by applicant (but this is often the case))
# * <b>Number of terms</b> (relevant to the applicant)
# * <b>Monthly cost</b> (relevant to the applicant)
# * Percentage offered amount of year income (amount / year_income) * 100
# * Percentage yearly cost (12 * monthly cost) of year income
# * Difference between offered amount and inital requested amount
#
# The attributes that are made bold, are attributes which the bank can vary from offer to offer (i.e. the variables of the offer). Other attributes have a relation to these attributes (e.g. last three attributes), while the other attributes is simply customer data. The hypothesis is that there are differences between (groups) of customers in the cognitive mechanisms behind the decision making process when faced with an offer.

# %% [markdown]
# Construct age attribute from the applicant's birthyear

# %%
made_offers["age"]= 2017 - made_offers.BIRTHYEAR

# %% [markdown]
# Percentage offered amount of year income ((offered_amount / year_income) * 100)

# %%
made_offers["percentage_amount_income"] = (made_offers.O_AMOUNT / made_offers.INCOMEAMOUNT_YEAR) * 100

# %% [markdown]
# Percentage yearly cost (12 * monthly cost) of year income

# %%
made_offers["percentage_cost_income"] = ((made_offers.O_MONTHLY_COST * 12) / made_offers.INCOMEAMOUNT_YEAR) * 100

# %% [markdown]
# Enrich offer data with application data (e.g. the applicant's initial requested amount , the application type (e.g. new credit, raise limit) and application loan goal (e.g. car, homeimprovements etc.)

# %%
unique_applications = applications.drop_duplicates(subset = 'A_ID')
unique_applications = unique_applications[['A_ID', 'A_INIT_REQ_AMT', 'A_APPLICATIONTYPE_DESC', 'A_LOANGOALTYPE_DESC']]
unique_applications.head()
# Out:
#       A_ID  A_INIT_REQ_AMT A_APPLICATIONTYPE_DESC        A_LOANGOALTYPE_DESC
# 0   719696         29000.0          Nieuw krediet                       Auto
# 8   719697         10000.0          Nieuw krediet                       Auto
# 13  719698         15000.0          Nieuw krediet          Woningverbetering
# 18  719699          5000.0          Nieuw krediet  Overname lopende leningen
# 29  719700          5000.0          Nieuw krediet        Niet gespecificeerd

# %% [markdown]
# Enrich offer data with initial requested amount (not necesarilly equal to offered amount), application type and loan goal

# %%
made_offers = made_offers.merge(unique_applications, on = "A_ID")

# %% [markdown]
# Calculate the difference between the offered amount and the initial requested amount

# %%
made_offers["diff_req_and_offered_amount"] = abs(made_offers.A_INIT_REQ_AMT - made_offers.O_AMOUNT)

# %%
corr = made_offers.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %% [markdown]
# ### <font color="green">Configure classification model</font>

# %% [markdown]
# Target attribute (i.e. label): O_SELECTED

# %%
req_amount = tf.feature_column.numeric_column('A_INIT_REQ_AMT')
income = tf.feature_column.numeric_column('INCOMEAMOUNT_YEAR')
number_of_children = tf.feature_column.numeric_column('NUMBER_OF_CHILDREN')
age = tf.feature_column.numeric_column('age')
o_amount = tf.feature_column.numeric_column('O_AMOUNT')
number_of_terms = tf.feature_column.numeric_column('NUMBER_OF_TERMS')
monthly_cost = tf.feature_column.numeric_column('O_MONTHLY_COST')
per_amount_income = tf.feature_column.numeric_column('percentage_amount_income')
per_cost_income = tf.feature_column.numeric_column('percentage_cost_income')
diff_req_and_offered_amount = tf.feature_column.numeric_column("diff_req_and_offered_amount")

# %%
made_offers.A_APPLICATIONTYPE_DESC.unique()
# Out:
# array(['Nieuw krediet', 'Limietverhoging'], dtype=object)

# %%
made_offers.A_LOANGOALTYPE_DESC.unique()
# Out:
# array(['Auto', 'Overname lopende leningen', 'Woningverbetering',
#        'Anders, zie toelichting', nan, 'Extra Bestedingsruimte',
#        'Restschuld woning', 'Niet gespecificeerd', 'Boot',
#        'Tourcaravan / camper', 'Motor', 'Belastingbetalingen',
#        'Zakelijk doel (no go)', 'Verbouwing aan het huis',
#        'verbouwing meubels/interieur', 'Verbouwing aan tuin',
#        'Onderhandse lening'], dtype=object)

# %%
made_offers.HOUSING_TYPE.unique()
# Out:
# array(['Koophuis', 'Huurhuis / Kamers', 'Thuiswonend/ Inwonend'], dtype=object)

# %%
made_offers.MARITAL_STATUS.unique()
# Out:
# array(['Samenwonend', 'Alleenstaand', 'Gehuwd',
#        'Geregistreerd partnerschap'], dtype=object)

# %%
loanGoal = tf.feature_column.categorical_column_with_vocabulary_list('A_LOANGOALTYPE_DESC',
                                                                           ['Auto', 'Woningverbetering', 'Overname lopende leningen',
                                                                            'Tourcaravan / camper', 'Anders, zie toelichting', 'nan',
                                                                            'Extra Bestedingsruimte', 'Niet gespecificeerd',
                                                                            'Restschuld woning', 'Boot', 'Motor', 'Belastingbetalingen',
                                                                            'Zakelijk doel (no go)', 'Schuldsanering (no go)',
                                                                            'Verbouwing aan het huis', 'verbouwing meubels/interieur',
                                                                            'Verbouwing aan tuin', 'Zakelijk pand (no go)', 'Onderhandse lening'])
applicationType = tf.feature_column.categorical_column_with_vocabulary_list('A_APPLICATIONTYPE_DESC',
                                                                           ['Nieuw krediet', 'Limietverhoging'])
housingType = tf.feature_column.categorical_column_with_vocabulary_list('HOUSING_TYPE',
                                                                          ['Koophuis', 'Thuiswonend/ Inwonend', 'Huurhuis / Kamers'])
gender = tf.feature_column.categorical_column_with_vocabulary_list('SEX', ['Man', 'Vrouw'])
marital_status = tf.feature_column.categorical_column_with_vocabulary_list('MARITAL_STATUS', ['Samenwonend', 'Alleenstaand',
                                                                                              'Gehuwd', 'Geregistreerd partnerschap'])

# %%
made_offers = made_offers[['NUMBER_OF_CHILDREN','NUMBER_OF_TERMS',
                           'O_MONTHLY_COST', 'percentage_amount_income', 'percentage_cost_income', 'MARITAL_STATUS',
                          "diff_req_and_offered_amount", 'A_LOANGOALTYPE_DESC', 'A_APPLICATIONTYPE_DESC',
                           'SEX', 'O_SELECTED']]
made_offers = made_offers.dropna(how = "any")
made_offers.shape
# Out:
# (16889, 11)

# %%
made_offers = made_offers.apply(preprocessing.LabelEncoder().fit_transform)

# %%
x_features = made_offers.drop('O_SELECTED', axis = 1)

# %%
pred_labels = made_offers['O_SELECTED']
pred_labels = preprocessing.LabelEncoder().fit_transform(pred_labels)

# %%
feat_cols = [tf.contrib.layers.real_valued_column("", dimension= x_features.shape[1])]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_features.as_matrix(), pred_labels, test_size = 0.2, random_state = 700)

# %%
classifier = tf.contrib.learn.DNNClassifier(feature_columns = feat_cols, hidden_units= [64, 32, 16],
                                            n_classes = 2, model_dir  ="tf_model")
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001BFCA87BF98>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': 'tf_model'}

# %%
pipe_tf = Pipeline([('std_scl', preprocessing.StandardScaler()), ('dnn', classifier)])

# %%
pipe_tf.fit(x_train, y_train, dnn__steps = 2000)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:642: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into tf_model\model.ckpt.
# INFO:tensorflow:loss = 0.694185, step = 1
# INFO:tensorflow:global_step/sec: 22.7403
# INFO:tensorflow:loss = 0.206928, step = 101 (4.398 sec)
# INFO:tensorflow:global_step/sec: 26.3775
# INFO:tensorflow:loss = 0.203174, step = 201 (3.790 sec)
# INFO:tensorflow:global_step/sec: 26.7065
# INFO:tensorflow:loss = 0.201005, step = 301 (3.745 sec)
# INFO:tensorflow:global_step/sec: 27.4506
# INFO:tensorflow:loss = 0.199459, step = 401 (3.643 sec)
# INFO:tensorflow:global_step/sec: 25.7964
# INFO:tensorflow:loss = 0.198219, step = 501 (3.877 sec)
# INFO:tensorflow:global_step/sec: 26.3938
# INFO:tensorflow:loss = 0.197152, step = 601 (3.788 sec)
# INFO:tensorflow:global_step/sec: 23.6515
# INFO:tensorflow:loss = 0.196249, step = 701 (4.229 sec)
# INFO:tensorflow:global_step/sec: 24.9458
# INFO:tensorflow:loss = 0.19541, step = 801 (4.009 sec)
# INFO:tensorflow:global_step/sec: 25.103
# INFO:tensorflow:loss = 0.194623, step = 901 (3.983 sec)
# INFO:tensorflow:global_step/sec: 26.0354
# INFO:tensorflow:loss = 0.193901, step = 1001 (3.842 sec)
# INFO:tensorflow:global_step/sec: 25.494
# INFO:tensorflow:loss = 0.193235, step = 1101 (3.922 sec)
# INFO:tensorflow:global_step/sec: 26.0491
# INFO:tensorflow:loss = 0.192614, step = 1201 (3.838 sec)
# INFO:tensorflow:global_step/sec: 26.3157
# INFO:tensorflow:loss = 0.192028, step = 1301 (3.801 sec)
# INFO:tensorflow:global_step/sec: 26.9422
# INFO:tensorflow:loss = 0.191462, step = 1401 (3.712 sec)
# INFO:tensorflow:global_step/sec: 25.8599
# INFO:tensorflow:loss = 0.190907, step = 1501 (3.867 sec)
# INFO:tensorflow:global_step/sec: 27.4751
# INFO:tensorflow:loss = 0.190374, step = 1601 (3.640 sec)
# INFO:tensorflow:global_step/sec: 26.9201
# INFO:tensorflow:loss = 0.189869, step = 1701 (3.714 sec)
# INFO:tensorflow:global_step/sec: 26.1692
# INFO:tensorflow:loss = 0.189375, step = 1801 (3.822 sec)
# INFO:tensorflow:global_step/sec: 25.7391
# INFO:tensorflow:loss = 0.188888, step = 1901 (3.885 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into tf_model\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.188413.
# Pipeline(steps=[('std_scl', StandardScaler(copy=True, with_mean=True, with_std=True)), ('dnn', DNNClassifier(params={'head': <tensorflow.contrib.learn.python.learn.estimators.head._BinaryLogisticHead object at 0x000001BFCA843A58>, 'hidden_units': [64, 32, 16], 'feature_columns': (_RealValuedColumn(column_nam...'gradient_clip_norm': None, 'embedding_lr_multipliers': None, 'input_layer_min_slice_size': None}))])

# %%
score = metrics.accuracy_score(y_test, list(pipe_tf.predict(x_test)))
print('Accuracy: {0:f}'.format(score))
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py:355: calling DNNClassifier.predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with outputs=None is deprecated and will be removed after 2017-03-01.
# Instructions for updating:
# Please switch to predict_classes, or set `outputs` argument.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\dnn.py:452: calling BaseEstimator.predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)
# INFO:tensorflow:Restoring parameters from tf_model\model.ckpt-2000
# Accuracy: 0.933985
